# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafa11-ai/data-science-2024/blob/main/Pertemuan1_Rafa_Hidayah_240401010203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama  : Rafa Hidayah
#
# NIM   : 240401010203
#
# Kelas : IF405

# %%
# Pertemuan 1 : Notebook Pertama Data Science

# Sel 1: Output sederhana
print ("\nHello, Data Science!")
print ("Selamat datang di mata kuliah pengantar data science!")

# Sel 2: Variabel dan tipe data dasar
nama      = "Rafa Hidayah" # String
angkatan  = 2024           # Integer
ipk       = 3.83           # Float
aktif     = True           # Boolean

print (f"\nNama: {nama}")
print (f"Angkatan: {angkatan}")
print (f"IPK: {ipk}")
print (f"Aktif: {aktif}")

# Sel 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print ("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate (tools, 1):
    print (f" {i}. {tool}")

# Sel 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan) :
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"\nHai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Rafa Hidayah", "Informatika", 2024)
print (hasil)
# Out:
# Nama: Rafa Hidayah
# NIM: 240401010203
# Kelas: IF405
#
# Hello, Data Science!
# Selamat datang di mata kuliah pengantar data science!
#
# Nama: Rafa Hidayah
# Angkatan: 2024
# IPK: 3.83
# Aktif: True
#
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub
#
# Hai! Saya Rafa Hidayah dari Informatika, angkatan 2024.

# %% [markdown]
# # Kesimpulan
# Pada pertemuan ini, saya mempelajari bahwa dasar - dasar penggunaan python, seperti menampilkan output ke layer, penggunaan variabel dengan berbagai tipe data (string, integer, dan boolean), penggunaan list dan perulangan (loop), serta pembuatan fungsi sederhana.
#
# # Temuan Utama
# - Python memiliki sintaks yang mudah dipahami dan digunakan dalam mengolah data.
# - Fungsi membantu membuat kode lebih terstruktur, dapat digunakan kembali, dan memudahkan pengelolaan program.
#
# # Keterbatasan
# - Program yang dibuat masih bersifat sederhana.
# - Masih menggunakan data yang ditulis langsung di dalam kode.
#
# # Pertanyaan
# - Bagaimana cara membaca data dari file CSV atau Excel menggunakan Python?
# - Apa saja fungsi pada python yang biasa digunakan dalam menganalisis data?
